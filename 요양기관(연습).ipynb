# %% [markdown]
# <a href="https://colab.research.google.com/github/kyungmo90/Ubion-Python/blob/main/%EC%9A%94%EC%96%91%EA%B8%B0%EA%B4%80(%EC%97%B0%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from pandas import DataFrame
import numpy as np
from pandas import *

# matplotlib는 시각화 라이브러리이고 pyplot은 matplotlib의 서브브패키지이다.
# pandas는 데이터 조작 및 분석용 라이브러리이고 DataFrame은 데이터분석에서 많이 사용하는 데이터 형태이다.
# numpy는 행렬을 다루기 위한 라이브러리이다.
# import * 은 라이브러리 전체를 불러오는 것이다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# 구글드라이브의 드라이브라는 폴더를 마운트
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df_LongTC = pd.read_csv("/content/drive/MyDrive/LongTC.CSV", encoding = "cp949")
df_LongTC

# 하드에 있는 엑셀파일중 하나를 구글 드라이브에 올리고 불러옴
# utf-8 오류가 떠서 cp949를 encoding해 한글 불러옴
# Out:
#        시도 관리지사\n운영센터  성별     연령구분    신청자   인정자   1등급   2등급    3등급    4등급   \
# 0      서울    영등포운영센터  합계      NaN  7,040  5,118   362   562  1,416  2,169
# 1     NaN    영등포운영센터   1       소계  2,194  1,542   106   166    434    633
# 2     NaN    영등포운영센터   1    65세미만    205    119    13    14     38     47
# 3     NaN    영등포운영센터   1  65세~69세    264    153    16    16     45     60
# 4     NaN    영등포운영센터   1  70세~74세    315    216    21    23     63     83
# ...   ...        ...  ..      ...    ...    ...   ...   ...    ...    ...
# 3400  NaN    서귀포운영센터   2  65세~69세    130     58     4     3     16     25
# 3401  NaN    서귀포운영센터   2  70세~74세    221    110    13     9     32     37
# 3402  NaN    서귀포운영센터   2  75세~79세    468    260    20    24     58     95
# 3403  NaN    서귀포운영센터   2  80세~84세    779    537    33    52    122    205
# 3404  NaN    서귀포운영센터   2    85세이상  1,558  1,208    70   147    372    447
#
#       5등급    인지지원등급   등급외자   등급외A    등급외B    등급외C
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_LongTC.boxplot(column="신청자", return_type="both")

# 신청자를 기준으로 박스플롯을 가져왔다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-a5794b454f8f> in <module>
# ----> 1 df_LongTC.boxplot(column="신청자", return_type="both")
#       2
#       3 # 신청자를 기준으로 박스플롯을 가져왔다.
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     392     import matplotlib.pyplot as plt
#     393
# --> 394     ax = boxplot(
#     395         self,
#     396         column=column,
#
# ...

# %%
q1 = df_LongTC["정원"].quantile(q=0.25)
q3 = df_LongTC["정원"].quantile(q=0.75)
IQR = q3-q1
IQR

# 3분위와 1분위에 있는 값을 빼서 IQR이라는 변수에 입력하고
# Out:
# 9.0

# %%
data_IQR = df_LongTC[(df_LongTC["정원"] < q3 + IQR * 1.5) & (df_LongTC["정원"] > q1 - IQR * 1.5)] #1.5는 약속
data_IQR

#1.5배수를 곱한 후 1분위와 3분위 사이에 있는 데이터들만 분류(21284개개)
# Out:
#                기관명       시도   시군구            기관유형  \
# 1           청운실버센터    서울특별시   종로구      노인요양공동생활가정
# 8          아름다운실버홈    서울특별시   종로구     노인요양시설(개정법)
# 9         남산실버복지센터    서울특별시    중구     노인요양시설(개정법)
# 11             효심원    서울특별시    중구      노인요양공동생활가정
# 12           사랑의 집    서울특별시   용산구      노인요양공동생활가정
# ...            ...      ...   ...             ...
# 26534  미소천사 주간보호센터  제주특별자치도   제주시  재가장기요양기관 주야간보호
# 26535    낭그늘노인복지센터  제주특별자치도   제주시  재가장기요양기관 주야간보호
# 26536     이도데이케어센터  제주특별자치도   제주시  재가장기요양기관 주야간보호
# 26541   김녕노인주간보호센터  제주특별자치도   제주시  재가장기요양기관 주야간보호
# 26545   (주)하늘빛복지타운  제주특별자치도  서귀포시  재가장기요양기관 주야간보호
#
#                                                      주소          전화번호    정원
# 1                           서울특별시 종로구 자하문로28길  29 (청운동)   02-730-4966   9.0
# 8                              서울특별시 종로구 평창길  123 (평창동)   02-394-0461  16.0
# 9                             서울특별시 중구 동호로5길  189 (신당동)  02-2238-9941  14.0
# ...

# %%
data_IQR["정원"].hist()

# IQR로 분류한 값들을 정원을 기준으로 막대그래프 출력

# %%
data_outlier=df_LongTC[(df_LongTC["정원"]>q3+IQR*1.5)]
data_outlier

# IQR에 1.5배 한 값을 넘어가는 이상치들을 출력해 보았다.(5261개개)
# Out:
#                   기관명       시도   시군구            기관유형  \
# 0             청운노인요양원    서울특별시   종로구     노인요양시설(개정법)
# 2             인자인케어센터    서울특별시   종로구     노인요양시설(개정법)
# 3            평창동시니어센터    서울특별시   종로구     노인요양시설(개정법)
# 4         아름다운뜰안에 요양원    서울특별시   종로구     노인요양시설(개정법)
# 5      서울여자간호대학교 휴먼캐슬    서울특별시   종로구     노인요양시설(개정법)
# ...               ...      ...   ...             ...
# 26540       온누리노인복지센터  제주특별자치도   제주시  재가장기요양기관 주야간보호
# 26542        미소노인복지센터  제주특별자치도  서귀포시  재가장기요양기관 주야간보호
# 26543        남원노인복지타운  제주특별자치도  서귀포시  재가장기요양기관 주야간보호
# 26544        색달노인복지센터  제주특별자치도  서귀포시  재가장기요양기관 주야간보호
# 26546        표선노인복지센터  제주특별자치도  서귀포시  재가장기요양기관 주야간보호
#
#                                         주소          전화번호    정원
# 0                  서울특별시 종로구 비봉길  76 (구기동)  02-3217-0057  45.0
# 2                서울특별시 종로구 평창17길  26 (평창동)   02-394-2234  42.0
# 3                서울특별시 종로구 평창15길  10 (평창동)   02-391-7936  68.0
# 4                서울특별시 종로구 평창21길  70 (평창동)   02-396-0461  38.0
# ...

# %%
df_LongTC.columns

# 칼럼만 출력해 보았다.
# Out:
# Index(['기관명', '시도', '시군구', '기관유형', '주소', '전화번호', '정원'], dtype='object')

# %%
under_9 = df_LongTC[df_LongTC["정원"] <= 9]
upper_9 = df_LongTC[df_LongTC["정원"] > 9]
print(under_9)
print(upper_9)

# IQR값인 9를 기준으로 변수를 입력했다.
# Out:
#                기관명       시도  시군구            기관유형  \
# 1           청운실버센터    서울특별시  종로구      노인요양공동생활가정
# 11             효심원    서울특별시   중구      노인요양공동생활가정
# 12           사랑의 집    서울특별시  용산구      노인요양공동생활가정
# 17          한마음너싱홈    서울특별시  성동구      노인요양공동생활가정
# 20         서울숲 요양원    서울특별시  성동구      노인요양공동생활가정
# ...            ...      ...  ...             ...
# 26514  정다운집 주간보호센터     경상남도  고성군  재가장기요양기관 주야간보호
# 26517    한사랑노인복지센터     경상남도  산청군  재가장기요양기관 주야간보호
# 26527     저청노인복지센터  제주특별자치도  제주시  재가장기요양기관 주야간보호
# 26534  미소천사 주간보호센터  제주특별자치도  제주시  재가장기요양기관 주야간보호
# 26541   김녕노인주간보호센터  제주특별자치도  제주시  재가장기요양기관 주야간보호
#
#                                           주소          전화번호   정원
# 1                서울특별시 종로구 자하문로28길  29 (청운동)   02-730-4966  9.0
# 11                 서울특별시 중구 청구로17길  98 (신당동)  02-2254-0833  9.0
# 12               서울특별시 용산구 효창원로15길  24 (산천동)   02-715-9020  9.0
# 17                 서울특별시 성동구 용답중앙길  91 (용답동)  02-2215-0174  9.0
# ...

# %%
upper_9.head()
# Out:
#               기관명     시도  시군구         기관유형                         주소  \
# 0         청운노인요양원  서울특별시  종로구  노인요양시설(개정법)    서울특별시 종로구 비봉길  76 (구기동)
# 2         인자인케어센터  서울특별시  종로구  노인요양시설(개정법)  서울특별시 종로구 평창17길  26 (평창동)
# 3        평창동시니어센터  서울특별시  종로구  노인요양시설(개정법)  서울특별시 종로구 평창15길  10 (평창동)
# 4     아름다운뜰안에 요양원  서울특별시  종로구  노인요양시설(개정법)  서울특별시 종로구 평창21길  70 (평창동)
# 5  서울여자간호대학교 휴먼캐슬  서울특별시  종로구  노인요양시설(개정법)   서울특별시 종로구 평창길  318 (평창동)
#
#            전화번호    정원
# 0  02-3217-0057  45.0
# 2   02-394-2234  42.0
# 3   02-391-7936  68.0
# 4   02-396-0461  38.0
# 5   02-391-8464  38.0

# %%
under_9.head()
# Out:
#         기관명     시도  시군구        기관유형                                     주소  \
# 1    청운실버센터  서울특별시  종로구  노인요양공동생활가정            서울특별시 종로구 자하문로28길  29 (청운동)
# 11      효심원  서울특별시   중구  노인요양공동생활가정              서울특별시 중구 청구로17길  98 (신당동)
# 12    사랑의 집  서울특별시  용산구  노인요양공동생활가정            서울특별시 용산구 효창원로15길  24 (산천동)
# 17   한마음너싱홈  서울특별시  성동구  노인요양공동생활가정              서울특별시 성동구 용답중앙길  91 (용답동)
# 20  서울숲 요양원  서울특별시  성동구  노인요양공동생활가정  서울특별시 성동구 뚝섬로  401-2 4층 (성수동2가, 일산빌딩)
#
#             전화번호   정원
# 1    02-730-4966  9.0
# 11  02-2254-0833  9.0
# 12   02-715-9020  9.0
# 17  02-2215-0174  9.0
# 20  02-6204-7227  9.0

# %%
# !sudo apt-get install -y fonts-nanum #폰트 다운로드 리눅스 명령어
# !sudo fc-cache -f -vv
# !rm ~/.cache/matplotlib -rf

#리눅스 명령어로 나눔폰트를 받았다.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (23.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'NanumBarunGothic')

# 표의 폰트를 바꿨다.
